# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from pandas.plotting import scatter_matrix
# import warnings
# warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('project.csv')
df
# Out:
#         ID  Business Guaranteed_Approved _Loan  \
# 0        0  Existing             Rs.33121600.0
# 1        1       New             Rs.32735520.0
# 2        2  Existing              Rs.1422400.0
# 3        3       New              Rs.2032000.0
# 4        4  Existing             Rs.22981920.0
# ...    ...       ...                       ...
# 9994  9994  Existing              Rs.1422400.0
# 9995  9995  Existing              Rs.4291584.0
# 9996  9996  Existing               Rs.447040.0
# 9997  9997       New              Rs.2357120.0
# 9998  9998       New               Rs.812800.0
#
#                       Borrower_Name  Low_Documentation_Loan Demography  \
# 0         STANDARD PARTS CORPORATION                     No  Undefined
# 1               FRANK & KERI AMESTOY                     No      Urban
# 2                   TELECOMMQC L L C                     No      Urban
# 3     K & A AUTOMOTIVE, INC. DBA MUF                     No      Urban
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         9999 non-null   int64
#  1   Business                   9999 non-null   object
#  2   Guaranteed_Approved _Loan  9999 non-null   object
#  3   Borrower_Name              9998 non-null   object
#  4   Low_Documentation_Loan     9958 non-null   object
#  5   Demography                 9999 non-null   object
#  6   Count_Employees            9999 non-null   int64
#  7   Loan_Approved_Gross        9999 non-null   object
#  8   Loan_Term                  9999 non-null   int64
#  9   Code_Franchise             9999 non-null   int64
#  10  Name_Of_Bank               9999 non-null   object
#  11  Revolving_Credit_Line      9951 non-null   object
#  12  Target                     9999 non-null   int64
# dtypes: int64(5), object(8)
# ...

# %%
df.shape
# Out:
# (9999, 13)

# %%
df.isnull().sum()
# Out:
# ID                            0
# Business                      0
# Guaranteed_Approved _Loan     0
# Borrower_Name                 1
# Low_Documentation_Loan       41
# Demography                    0
# Count_Employees               0
# Loan_Approved_Gross           0
# Loan_Term                     0
# Code_Franchise                0
# Name_Of_Bank                  0
# Revolving_Credit_Line        48
# Target                        0
# dtype: int64

# %%
df.dropna()
# Out:
#         ID  Business Guaranteed_Approved _Loan  \
# 0        0  Existing             Rs.33121600.0
# 1        1       New             Rs.32735520.0
# 2        2  Existing              Rs.1422400.0
# 3        3       New              Rs.2032000.0
# 4        4  Existing             Rs.22981920.0
# ...    ...       ...                       ...
# 9994  9994  Existing              Rs.1422400.0
# 9995  9995  Existing              Rs.4291584.0
# 9996  9996  Existing               Rs.447040.0
# 9997  9997       New              Rs.2357120.0
# 9998  9998       New               Rs.812800.0
#
#                       Borrower_Name  Low_Documentation_Loan Demography  \
# 0         STANDARD PARTS CORPORATION                     No  Undefined
# 1               FRANK & KERI AMESTOY                     No      Urban
# 2                   TELECOMMQC L L C                     No      Urban
# 3     K & A AUTOMOTIVE, INC. DBA MUF                     No      Urban
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# Business                      0
# Guaranteed_Approved _Loan     0
# Borrower_Name                 1
# Low_Documentation_Loan       41
# Demography                    0
# Count_Employees               0
# Loan_Approved_Gross           0
# Loan_Term                     0
# Code_Franchise                0
# Name_Of_Bank                  0
# Revolving_Credit_Line        48
# Target                        0
# dtype: int64

# %%
df['ID'].plot(kind='bar')
plt.title('ID')
plt.show()

# %%
df['Count_Employees'].plot(kind='hist')
plt.title('Employee')
plt.show()

# %%
df['Loan_Term'].plot(kind='hist')
plt.title('Loan_Term')
plt.show()

# %%
df['Target'].plot(kind='bar')
plt.title('Target')
plt.show()

# %%
df['Count_Employees'].plot(kind='hist')
plt.title('Count_Employees')
plt.show()

# %%
df['ID'].plot(kind='box')
plt.title('ID')
plt.show()

# %%
 df['Business'].dropna()
# Out:
# 0       Existing
# 1            New
# 2       Existing
# 3            New
# 4       Existing
#           ...
# 9994    Existing
# 9995    Existing
# 9996    Existing
# 9997         New
# 9998         New
# Name: Business, Length: 9999, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         9999 non-null   int64
#  1   Business                   9999 non-null   object
#  2   Guaranteed_Approved _Loan  9999 non-null   object
#  3   Borrower_Name              9998 non-null   object
#  4   Low_Documentation_Loan     9958 non-null   object
#  5   Demography                 9999 non-null   object
#  6   Count_Employees            9999 non-null   int64
#  7   Loan_Approved_Gross        9999 non-null   object
#  8   Loan_Term                  9999 non-null   int64
#  9   Code_Franchise             9999 non-null   int64
#  10  Name_Of_Bank               9999 non-null   object
#  11  Revolving_Credit_Line      9951 non-null   object
#  12  Target                     9999 non-null   int64
# dtypes: int64(5), object(8)
# ...

# %%
df['Business'] = pd.to_numeric(df['Business'], errors='coerce')
df['Business'].isna().sum()
# Out:
# np.int64(9992)

# %%
df['Business'].plot(kind='box')
plt.title('Boxplot of Business Data')
plt.ylabel('Values')
plt.show()

# %%
df['Guaranteed_Approved _Loan'] = pd.to_numeric(df['Guaranteed_Approved _Loan'], errors='coerce')
df['Guaranteed_Approved _Loan'].isna().sum()
# Out:
# np.int64(9999)

# %%
df['Guaranteed_Approved _Loan'].plot(kind='box')
plt.title('Approved Loan')
plt.ylabel('Guaranteed_Approved _Loan')
plt.show()

# %%
df['Low_Documentation_Loan'] = pd.to_numeric(df['Low_Documentation_Loan'], errors='coerce')
df['Low_Documentation_Loan'].isnull().sum()
# Out:
# np.int64(9982)

# %%
df['Low_Documentation_Loan'].plot(kind='box')
plt.title('Low_Documentation_Loan')
plt.show()

# %%
df['Count_Employees'].plot(kind='box')
plt.title('Employee')
plt.show()

# %%
upper_limits=df['Count_Employees'].mean()+3*df['Count_Employees'].std()
lower_limits=df['Count_Employees'].mean()-3*df['Count_Employees'].std()
print('upper Limit',upper_limits)
print('lower_limits',lower_limits)
# Out:
# upper Limit 155.0315015057995
# lower_limits -136.13301165681457

# %%
df.loc[(df['Count_Employees']>upper_limits) | (df['Count_Employees']<lower_limits)]
# Out:
#         ID  Business  Guaranteed_Approved _Loan  \
# 354    354       NaN                        NaN
# 1191  1191       NaN                        NaN
# 1338  1338       NaN                        NaN
# 1605  1605       NaN                        NaN
# 2307  2307       NaN                        NaN
# 2494  2494       NaN                        NaN
# 2823  2823       NaN                        NaN
# 2973  2973       NaN                        NaN
# 3015  3015       NaN                        NaN
# 3298  3298       NaN                        NaN
# 3569  3569       NaN                        NaN
# 3703  3703       NaN                        NaN
# 4377  4377       NaN                        NaN
# 4920  4920       NaN                        NaN
# 5475  5475       NaN                        NaN
# 5826  5826       NaN                        NaN
# 6203  6203       NaN                        NaN
# 6897  6897       NaN                        NaN
# ...

# %%
new_df=df.loc[(df['Count_Employees']<=upper_limits) & (df['Count_Employees']>=lower_limits)]
print('old data',len(df))
print('new data',len(new_df))
print('Outliers:',len(df)-len(new_df))
# Out:
# old data 9999
# new data 9973
# Outliers: 26

# %%
new_df['Count_Employees'].plot(kind='box')
plt.title('Employee')
plt.show()

# %%
df['Loan_Term'].plot(kind='box')
plt.title('Loan Term')
plt.show()

# %%
upper_limits=df['Loan_Term'].mean()+3*df['Loan_Term'].std()
lower_limits=df['Loan_Term'].mean()-3*df['Loan_Term'].std()
print('upper Limit',upper_limits)
print('lower_limits',lower_limits)
# Out:
# upper Limit 502.7861014875791
# lower_limits -190.87331020845116

# %%
df.loc[(df['Loan_Term']>upper_limits) | (df['Loan_Term']<lower_limits)]
# Out:
#         ID  Business  Guaranteed_Approved _Loan    Borrower_Name   \
# 2671  2671       NaN                        NaN  HALES, EDWARD E.
#
#       Low_Documentation_Loan Demography  Count_Employees Loan_Approved_Gross  \
# 2671                     NaN  Undefined                1        Rs.8303564.8
#
#       Loan_Term  Code_Franchise         Name_Of_Bank Revolving_Credit_Line  \
# 2671        513               0  Dhanlaxmi Bank Ltd.                    No
#
#       Target
# 2671       1

# %%
new_df=df.loc[(df['Loan_Term']<=upper_limits) & (df['Loan_Term']>=lower_limits)]
print('old data',len(df))
print('new data',len(new_df))
print('Outliers:',len(df)-len(new_df))
# Out:
# old data 9999
# new data 9998
# Outliers: 1

# %%
new_df['Loan_Term'].plot(kind='box')
plt.title('Loan Term')
plt.show()

# %%
df['Code_Franchise'].plot(kind='box')
plt.title('Code Franchise')
plt.show()

# %%
upper_limits=df['Code_Franchise'].mean()+3*df['Code_Franchise'].std()
lower_limits=df['Code_Franchise'].mean()-3*df['Code_Franchise'].std()
print('upper Limit',upper_limits)
print('lower_limits',lower_limits)
df.loc[(df['Code_Franchise']>upper_limits) | (df['Code_Franchise']<lower_limits)]
# Out:
# upper Limit 41447.75334561316
# lower_limits -35906.81665194379
#         ID  Business  Guaranteed_Approved _Loan  \
# 16      16       NaN                        NaN
# 22      22       NaN                        NaN
# 86      86       NaN                        NaN
# 115    115       NaN                        NaN
# 132    132       NaN                        NaN
# ...    ...       ...                        ...
# 9814  9814       NaN                        NaN
# 9843  9843       NaN                        NaN
# 9856  9856       NaN                        NaN
# 9876  9876       NaN                        NaN
# 9895  9895       NaN                        NaN
#
#                       Borrower_Name   Low_Documentation_Loan Demography  \
# 16                    AR BROOKS, LLC                     NaN      Urban
# 22                         TACO MAYO                     NaN  Undefined
# 86    THE LITTLE GYM OF COEUR, MISSO                     NaN      Urban
# ...

# %%
new_df=df.loc[(df['Code_Franchise']<=upper_limits) & (df['Code_Franchise']>=lower_limits)]
print('old data',len(df))
print('new data',len(new_df))
print('Outliers:',len(df)-len(new_df))
# Out:
# old data 9999
# new data 9669
# Outliers: 330

# %%
new_df['Code_Franchise'].plot(kind='box')
plt.title('Code Franchise')
plt.show()

# %%
df['Name_Of_Bank'] = pd.to_numeric(df['Name_Of_Bank'], errors='coerce')
df['Name_Of_Bank'].isnull().sum()
# Out:
# np.int64(9999)

# %%
df['Name_Of_Bank'].plot(kind='box')
plt.title('Name_Of_Bank')
plt.show()

# %%
upper_limits=df['Name_Of_Bank'].mean()+3*df['Name_Of_Bank'].std()
lower_limits=df['Name_Of_Bank'].mean()-3*df['Name_Of_Bank'].std()
print('upper Limit',upper_limits)
print('lower limits',lower_limits)
df.loc[(df['Name_Of_Bank']>upper_limits) | (df['Name_Of_Bank']<lower_limits)]
# Out:
# upper Limit nan
# lower limits nan
# Empty DataFrame
# Columns: [ID, Business, Guaranteed_Approved _Loan, Borrower_Name , Low_Documentation_Loan, Demography, Count_Employees, Loan_Approved_Gross, Loan_Term, Code_Franchise, Name_Of_Bank, Revolving_Credit_Line, Target]
# Index: []

# %%
df['Revolving_Credit_Line'] = pd.to_numeric(df['Revolving_Credit_Line'], errors='coerce')
df['Revolving_Credit_Line'].isnull().sum()
# Out:
# np.int64(7153)

# %%
df['Revolving_Credit_Line'].plot(kind='box')
plt.title('Revolving Credit Line')
plt.show()

# %%
upper_limits=df['Name_Of_Bank'].mean()+3*df['Name_Of_Bank'].std()
lower_limits=df['Name_Of_Bank'].mean()-3*df['Name_Of_Bank'].std()
print('upper Limit',upper_limits)
print('lower limits',lower_limits)
df.loc[(df['Name_Of_Bank']>upper_limits) | (df['Name_Of_Bank']<lower_limits)]
# Out:
# upper Limit nan
# lower limits nan
# Empty DataFrame
# Columns: [ID, Business, Guaranteed_Approved _Loan, Borrower_Name , Low_Documentation_Loan, Demography, Count_Employees, Loan_Approved_Gross, Loan_Term, Code_Franchise, Name_Of_Bank, Revolving_Credit_Line, Target]
# Index: []

# %%
df['Target'].plot(kind='box')
plt.title('Target')
plt.show()

# %%
upper_limits=df['Name_Of_Bank'].mean()+3*df['Name_Of_Bank'].std()
lower_limits=df['Name_Of_Bank'].mean()-3*df['Name_Of_Bank'].std()
print('upper Limit',upper_limits)
print('lower limits',lower_limits)
df.loc[(df['Name_Of_Bank']>upper_limits) | (df['Name_Of_Bank']<lower_limits)]
# Out:
# upper Limit nan
# lower limits nan
# Empty DataFrame
# Columns: [ID, Business, Guaranteed_Approved _Loan, Borrower_Name , Low_Documentation_Loan, Demography, Count_Employees, Loan_Approved_Gross, Loan_Term, Code_Franchise, Name_Of_Bank, Revolving_Credit_Line, Target]
# Index: []

# %%
new_df.dtypes
# Out:
# ID                             int64
# Business                     float64
# Guaranteed_Approved _Loan    float64
# Borrower_Name                 object
# Low_Documentation_Loan       float64
# Demography                    object
# Count_Employees                int64
# Loan_Approved_Gross           object
# Loan_Term                      int64
# Code_Franchise                 int64
# Name_Of_Bank                  object
# Revolving_Credit_Line         object
# Target                         int64
# dtype: object

# %%
new_df.head()
# Out:
#    ID  Business  Guaranteed_Approved _Loan                  Borrower_Name   \
# 0   0       NaN                        NaN      STANDARD PARTS CORPORATION
# 1   1       NaN                        NaN            FRANK & KERI AMESTOY
# 2   2       NaN                        NaN                TELECOMMQC L L C
# 3   3       NaN                        NaN  K & A AUTOMOTIVE, INC. DBA MUF
# 4   4       NaN                        NaN                    SUNBEAM DELI
#
#    Low_Documentation_Loan Demography  Count_Employees Loan_Approved_Gross  \
# 0                     NaN  Undefined               38       Rs.40640000.0
# 1                     NaN      Urban                6       Rs.43647360.0
# 2                     NaN      Urban                4        Rs.2844800.0
# 3                     NaN      Urban                7        Rs.4064000.0
# 4                     NaN      Urban                4       Rs.30642560.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lab_enc=LabelEncoder()
new_df['Demography']=lab_enc.fit_transform(new_df['Demography'])
new_df
# Out:
#         ID  Business  Guaranteed_Approved _Loan  \
# 0        0       NaN                        NaN
# 1        1       NaN                        NaN
# 2        2       NaN                        NaN
# 3        3       NaN                        NaN
# 4        4       NaN                        NaN
# ...    ...       ...                        ...
# 9994  9994       NaN                        NaN
# 9995  9995       NaN                        NaN
# 9996  9996       NaN                        NaN
# 9997  9997       NaN                        NaN
# 9998  9998       NaN                        NaN
#
#                       Borrower_Name   Low_Documentation_Loan  Demography  \
# 0         STANDARD PARTS CORPORATION                     NaN           1
# 1               FRANK & KERI AMESTOY                     NaN           2
# 2                   TELECOMMQC L L C                     NaN           2
# 3     K & A AUTOMOTIVE, INC. DBA MUF                     NaN           2
# ...

# %%
leb_enc=LabelEncoder()
new_df['Loan_Approved_Gross']=lab_enc.fit_transform(new_df['Loan_Approved_Gross'])
new_df
# Out:
#         ID  Business  Guaranteed_Approved _Loan  \
# 0        0       NaN                        NaN
# 1        1       NaN                        NaN
# 2        2       NaN                        NaN
# 3        3       NaN                        NaN
# 4        4       NaN                        NaN
# ...    ...       ...                        ...
# 9994  9994       NaN                        NaN
# 9995  9995       NaN                        NaN
# 9996  9996       NaN                        NaN
# 9997  9997       NaN                        NaN
# 9998  9998       NaN                        NaN
#
#                       Borrower_Name   Low_Documentation_Loan  Demography  \
# 0         STANDARD PARTS CORPORATION                     NaN           1
# 1               FRANK & KERI AMESTOY                     NaN           2
# 2                   TELECOMMQC L L C                     NaN           2
# 3     K & A AUTOMOTIVE, INC. DBA MUF                     NaN           2
# ...

# %%
new_df
# Out:
#         ID  Business  Guaranteed_Approved _Loan  \
# 0        0       NaN                        NaN
# 1        1       NaN                        NaN
# 2        2       NaN                        NaN
# 3        3       NaN                        NaN
# 4        4       NaN                        NaN
# ...    ...       ...                        ...
# 9994  9994       NaN                        NaN
# 9995  9995       NaN                        NaN
# 9996  9996       NaN                        NaN
# 9997  9997       NaN                        NaN
# 9998  9998       NaN                        NaN
#
#                       Borrower_Name   Low_Documentation_Loan  Demography  \
# 0         STANDARD PARTS CORPORATION                     NaN           1
# 1               FRANK & KERI AMESTOY                     NaN           2
# 2                   TELECOMMQC L L C                     NaN           2
# 3     K & A AUTOMOTIVE, INC. DBA MUF                     NaN           2
# ...

# %%
newww=new_df.dropna(axis=1)

# %%
newww
# Out:
#         ID  Demography  Count_Employees  Loan_Approved_Gross  Loan_Term  \
# 0        0           1               38                  886        126
# 1        1           2                6                  939        123
# 2        2           2                4                  636         90
# 3        3           2                7                  885        126
# 4        4           2                4                  688        104
# ...    ...         ...              ...                  ...        ...
# 9994  9994           2                5                  636         36
# 9995  9995           1                2                 1038         46
# 9996  9996           2                3                 1470         88
# 9997  9997           0                1                 1009          6
# 9998  9998           2                2                  284        126
#
#       Code_Franchise                         Name_Of_Bank  Target
# ...

# %%
leb_enc=LabelEncoder()
newww['Name_Of_Bank']=lab_enc.fit_transform(new_df['Name_Of_Bank'])
newww
# Out:
#         ID  Demography  Count_Employees  Loan_Approved_Gross  Loan_Term  \
# 0        0           1               38                  886        126
# 1        1           2                6                  939        123
# 2        2           2                4                  636         90
# 3        3           2                7                  885        126
# 4        4           2                4                  688        104
# ...    ...         ...              ...                  ...        ...
# 9994  9994           2                5                  636         36
# 9995  9995           1                2                 1038         46
# 9996  9996           2                3                 1470         88
# 9997  9997           0                1                 1009          6
# 9998  9998           2                2                  284        126
#
#       Code_Franchise  Name_Of_Bank  Target
# 0                  1            11       0
# ...

# %%
x=newww.drop('Target',axis=1)
y=newww['Target']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,random_state=23)

# %%
x_train
# Out:
# array([[-0.66966982,  0.81764682, -0.04876862, ...,  1.7619414 ,
#         -0.14142021, -0.33977155],
#        [ 0.38740852,  0.81764682, -0.08939443, ..., -0.39137268,
#         -0.14142021, -0.22984638],
#        [-0.60390528, -0.63456242, -0.13002024, ..., -0.25356058,
#         -0.14142021,  0.37474205],
#        ...,
#        [ 0.48086338, -0.63456242,  0.13404753, ..., -0.25356058,
#         -0.14142021, -0.33977155],
#        [ 1.58397689,  0.81764682, -0.17064605, ..., -0.58947758,
#         10.81338396,  0.51214851],
#        [ 1.41541201, -2.08677167, -0.15033315, ..., -0.56363781,
#         -0.14142021,  0.64955497]])
